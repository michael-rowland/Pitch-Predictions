# %% [markdown]
# ## NOTES
#
# ---
#
# Features:
# - Shifting?
# - Home/Away
#
# Per pitcher models
#
# Exponential Smoothing
#
# Permutation Importances

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    # !pip install category_encoders==2.*
    # !pip install pybaseball

# If you're working locally:
else:
    DATA_PATH = '../data/'

# %%
# import os
import numpy as np
import pandas as pd
import category_encoders as ce
from pybaseball import statcast_pitcher

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## DATA PROCESSING
#
# ---

# %%
def pitch_encoding(df):
  '''
  uses OneHotEncoder to encode pitch_name to seperate columns
  '''
  df = df.copy()

  encoder = ce.OneHotEncoder(use_cat_names=True)
  encoded = encoder.fit_transform(df['previous_pitch'])
  # careful on the 'on' parameter, may cause issues later
  df = pd.merge(df, encoded, how='outer', on=df.index)
  df = df.drop(['key_0', 'previous_pitch_nan'], axis=1)
  
  # MAY WANT TO CHANGE THIS NAN SOMETIME
  # df.loc[0, 'previous_pitch']
  
  return df

# %%
def pitch_tendency(df, window):
  '''
  THIS IS INCOMPLETE, BUT MVP, FIRST ROWS OF WINDOW WHILE ROW < WINDOW
  AVERAGES INCLUDE FIRST ROW, WHICH ARE ALL ZEROS, SO SUM OF ALL TENDENCIES
  DOES NOT EQUAL 1.0. THIS IS ONLY AN ISSUE FOR FIRST 5, AND COULD BE UPDATED 
  BY REMOVING MIN_PERIODS=1 PARAMETER
  '''
  df = df.copy()

  pitches = df[[col for col in df if col.startswith('previous_pitch_')]]

  for i in pitches.columns:
    df[f'{i[-2:]}_tendency_{window}'] = df[i].rolling(
        window, min_periods=1).mean()
    
  return df

# %%
def pitch_counter(df):
  '''
  adds columns of cumulative count for each specific pitch type
  '''
  df = df.copy()

  pitches = [col for col in df if col.startswith('previous_pitch_')]
  
  for pitch in pitches:
    df[f'count_{i[-2:]}'] = (df[pitch]] == 1).cumsum()

#     counter = 0
#     target = f'{i[-2:]}_count'
#     df[target] = 0
#     for j in range(len(df)):
#       if df.loc[j, i] == 1:
#         counter += 1
#       df.loc[j, target] = counter
  
  return df

# %%
def total_pitches(df):
  '''
  calculates total pitches (prior to current/target pitch) since entering
  the game
  '''
  df = df.copy()

  df['pitch_total_prior'] = df.groupby('game_date').cumcount(ascending=True)

  return df

# %%
def score_margin(df):
  '''
  calculates the score margin for the pitcher's team
  '''
  df = df.copy()

  df['score_margin'] = df['fld_score'] - df['bat_score']
  df = df.drop(['fld_score', 'bat_score'], axis=1)

  return df

# %%
def pitcher_advantage(df):
  '''
  generates categorical 'pitcher_advantage' variable based on the count
  '''
  df = df.copy()

  advantages = {'0-0':'neutral', '0-1':'ahead', '0-2':'ahead', '1-0':'neutral', 
                '1-1':'neutral', '1-2':'ahead', '2-0':'behind', '2-1':'neutral',
                '2-2':'ahead', '3-0':'behind', '3-1':'behind', '3-2':'neutral'}

  df['count'] = df['balls'].astype(str) + '-' + df['strikes'].astype(str)
  df['pitcher_advantage'] = df['count'].map(advantages)
  df = df.drop('count', axis=1)

  return df

# %%
def baserunners_mapping(df):
  '''
  maps baserunner to boolean values
  '''
  df = df.copy()

  df['on_1b'] = df['on_1b'].notnull()
  df['on_2b'] = df['on_2b'].notnull()
  df['on_3b'] = df['on_3b'].notnull()
  
  df['baserunner'] = df['on_1b'] | df['on_2b'] | df['on_3b']

  return df

# %%
def at_bat_counter(df):
  '''
  generates column for number of batters faced
  '''
  df = df.copy()

  df['at_bat_count'] = df.groupby('at_bat_number').ngroup(ascending=True)+1
  df = df.drop('at_bat_number', axis=1)

  return df

# %%
def pitch_cleaning(df):
  '''
  cleans target ('pitch_type'), dropping NaN's (bad data) and pitch out's
  '''
  df = df.copy()

  df = df.dropna(subset=['pitch_type'])
  
  df['pitch_type'] = df['pitch_type'].str.lower()
  remove_pitches = ['po']
  df = df[~df['pitch_type'].isin(remove_pitches)]
  df = df.drop('pitch_name', axis=1)

  return df

# %%
def pitch_map(df):
  '''
  generates dictionary mapping 'pitch_type' to 'pitch_name'
  '''
  df = df.copy()

  df = df.dropna(subset=['pitch_type', 'pitch_name'])
  pitch_types = df['pitch_name'].unique().tolist()
  pitch_types_abv = [i.lower() for i in df['pitch_type'].unique().tolist()]
  
  return dict(zip(pitch_types_abv, pitch_types))

# %%
def wrangle_game(df):
  '''
  this function does data wrangling and feature engineering on a per game basis
  '''
  df = df.copy()

  # REORDERS FIRST PITCH TO LAST
  df = df.reindex(index=df.index[::-1])
  df = df.reset_index(drop=True)

  df = pitch_cleaning(df)
  df['previous_pitch'] = df['pitch_type'].shift(1)
  df['strike_previous'] = df['type'].shift(1) == 'S'
  # this may need to be encoded somehow
  df['pitch_location_previous'] = df['zone'].shift(1)
  df = pitch_encoding(df)
  df = pitch_tendency(df, 5)
  df = pitch_tendency(df, 10)
  df = pitch_tendency(df, 20)
  df = pitch_counter(df)
  df = total_pitches(df)
  df = score_margin(df)
  df = pitcher_advantage(df)
  df = baserunners_mapping(df)
  df = at_bat_counter(df)
  
  return df

# %%
sample = 'https://raw.githubusercontent.com/michael-rowland/Pitch-Predictions/master/sample.csv'
df = pd.read_csv(sample)
df = df[df['game_date'] == '2018-09-28']
df = df[features]
df = wrangle_game(df)

# %%
def strike_encoding(df):
  '''
  uses OneHotEncoder to encode pitch_name to seperate columns if previous pitch was strike
  '''
  df = df.copy()
  
  s = df['strike_previous'] == True
  df['strike_pitch'] = s.mask(s, df['previous_pitch'])
  
  encoder = ce.OneHotEncoder(use_cat_names=True)
  encoded = encoder.fit_transform(df['strike_pitch'])
  # careful on the 'on' parameter, may cause issues later
  df = pd.merge(df, encoded, how='outer', on=df.index)
  df = df.drop(['key_0', 'strike_pitch_False'], axis=1)
  
  return df

df = strike_encoding(df)

# %%
def strike_percentage(df, percentage=True):
  '''
  creates column for each pitch type of percentage (or raw count) pitch has been
  thrown for a strike.
  
  COULD FURTHER ENGINEER STRIKE PERCENTAGE TO BE BASED OFF OF NUMBER OF STRIKES 
  RATHER THAN TOTAL PITCHES
  '''
  df = df.copy()

  pitches = [col for col in df if col.startswith('strike_pitch_')]

  for i in pitches:
    if percentage:
      df[f'{i[-2:]}_cumulative_strikes'] = (df[f'strike_pitch_{i[-2:]}'] == 1).cumsum() / df['pitch_total_prior']
    else:
      df[f'{i[-2:]}_cumulative_strikes'] = (df[f'strike_pitch_{i[-2:]}'] == 1).cumsum()
      
  return df

df = strike_percentage(df, percentage=True)

# %%
def strike_counter(df, window):
  '''
  creates columns of number of previous n=window strikes thrown for each pitch 
  type
  '''
  df = df.copy()
  
  pitches = [col for col in df if col.startswith('strike_pitch_')]
  
  for i in pitches:
    target = f'{i[-2:]}_strike_tendency_{window}'
    df[target] = df[df['strike_pitch'] != False][i].rolling(window, 
                                                            min_periods=1).sum()
    df[target] = df[target].fillna(method='ffill')

  return df

df = strike_counter(df, 5)
df.head(15).T
# Out:
#                                  0           1           2           3   \
# pitch_type                       ff          ch          ff          ff
# game_date                2018-09-28  2018-09-28  2018-09-28  2018-09-28
# stand                             L           L           L           L
# balls                             0           0           1           1
# strikes                           0           1           1           2
# on_3b                         False       False       False       False
# on_2b                         False       False       False       False
# on_1b                         False       False       False       False
# outs_when_up                      0           0           0           0
# inning                            1           1           1           1
# type                              S           B           S           S
# zone                              9          13           1           6
# previous_pitch                  NaN          ff          ch          ff
# strike_previous               False        True       False        True
# pitch_location_previous         NaN           9          13           1
# previous_pitch_ff                 0           1           0           1
# previous_pitch_ch                 0           0           1           0
# previous_pitch_cu                 0           0           0           0
# previous_pitch_ft                 0           0           0           0
# ff_tendency_5                     0         0.5    0.333333         0.5
# ch_tendency_5                     0           0    0.333333        0.25
# cu_tendency_5                     0           0           0           0
# ft_tendency_5                     0           0           0           0
# ff_tendency_10                    0         0.5    0.333333         0.5
# ch_tendency_10                    0           0    0.333333        0.25
# cu_tendency_10                    0           0           0           0
# ft_tendency_10                    0           0           0           0
# ff_tendency_20                    0         0.5    0.333333         0.5
# ch_tendency_20                    0           0    0.333333        0.25
# cu_tendency_20                    0           0           0           0
# ft_tendency_20                    0           0           0           0
# ff_count                          0           1           1           2
# ch_count                          0           0           1           1
# cu_count                          0           0           0           0
# ft_count                          0           0           0           0
# pitch_total_prior                 0           1           2           3
# score_margin                      0           0           0           0
# pitcher_advantage           neutral       ahead     neutral       ahead
# baserunner                    False       False       False       False
# at_bat_count                      1           1           1           1
# strike_pitch                  False          ff       False          ff
# strike_pitch_ff                   0           1           0           1
# strike_pitch_cu                   0           0           0           0
# strike_pitch_ft                   0           0           0           0
# strike_pitch_ch                   0           0           0           0
# ff_cumulative_strikes           NaN           1         0.5    0.666667
# cu_cumulative_strikes           NaN           0           0           0
# ft_cumulative_strikes           NaN           0           0           0
# ch_cumulative_strikes           NaN           0           0           0
# ff_strike_tendency_5            NaN           1           1           2
# cu_strike_tendency_5            NaN           0           0           0
# ft_strike_tendency_5            NaN           0           0           0
# ch_strike_tendency_5            NaN           0           0           0
#
#                                  4           5           6           7   \
# pitch_type                       ff          ff          cu          ff
# game_date                2018-09-28  2018-09-28  2018-09-28  2018-09-28
# stand                             L           L           L           L
# balls                             0           0           0           1
# strikes                           0           1           2           2
# on_3b                         False       False       False       False
# on_2b                         False       False       False       False
# on_1b                         False       False       False       False
# outs_when_up                      1           1           1           1
# inning                            1           1           1           1
# type                              S           S           B           S
# zone                              9           3          14           6
# previous_pitch                   ff          ff          ff          cu
# strike_previous                True        True        True       False
# pitch_location_previous           6           9           3          14
# previous_pitch_ff                 1           1           1           0
# previous_pitch_ch                 0           0           0           0
# previous_pitch_cu                 0           0           0           1
# previous_pitch_ft                 0           0           0           0
# ff_tendency_5                   0.6         0.8         0.8         0.8
# ch_tendency_5                   0.2         0.2         0.2           0
# cu_tendency_5                     0           0           0         0.2
# ft_tendency_5                     0           0           0           0
# ff_tendency_10                  0.6    0.666667    0.714286       0.625
# ch_tendency_10                  0.2    0.166667    0.142857       0.125
# cu_tendency_10                    0           0           0       0.125
# ft_tendency_10                    0           0           0           0
# ff_tendency_20                  0.6    0.666667    0.714286       0.625
# ch_tendency_20                  0.2    0.166667    0.142857       0.125
# cu_tendency_20                    0           0           0       0.125
# ft_tendency_20                    0           0           0           0
# ff_count                          3           4           5           5
# ch_count                          1           1           1           1
# cu_count                          0           0           0           1
# ft_count                          0           0           0           0
# pitch_total_prior                 4           5           6           7
# score_margin                      0           0           0           0
# pitcher_advantage           neutral       ahead       ahead       ahead
# baserunner                    False       False       False       False
# at_bat_count                      2           2           2           2
# strike_pitch                     ff          ff          ff       False
# strike_pitch_ff                   1           1           1           0
# strike_pitch_cu                   0           0           0           0
# strike_pitch_ft                   0           0           0           0
# strike_pitch_ch                   0           0           0           0
# ff_cumulative_strikes          0.75         0.8    0.833333    0.714286
# cu_cumulative_strikes             0           0           0           0
# ft_cumulative_strikes             0           0           0           0
# ch_cumulative_strikes             0           0           0           0
# ff_strike_tendency_5              3           4           5           5
# cu_strike_tendency_5              0           0           0           0
# ft_strike_tendency_5              0           0           0           0
# ch_strike_tendency_5              0           0           0           0
#
#                                  8           9           10          11  \
# pitch_type                       cu          ff          cu          cu
# game_date                2018-09-28  2018-09-28  2018-09-28  2018-09-28
# stand                             R           R           R           R
# balls                             0           0           1           2
# strikes                           0           1           1           1
# on_3b                         False       False       False       False
# on_2b                         False       False       False       False
# on_1b                         False       False       False       False
# outs_when_up                      2           2           2           2
# inning                            1           1           1           1
# type                              S           B           B           S
# zone                             14          11          14          14
# previous_pitch                   ff          cu          ff          cu
# strike_previous                True        True       False       False
# pitch_location_previous           6          14          11          14
# previous_pitch_ff                 1           0           1           0
# previous_pitch_ch                 0           0           0           0
# previous_pitch_cu                 0           1           0           1
# previous_pitch_ft                 0           0           0           0
# ff_tendency_5                   0.8         0.6         0.6         0.4
# ch_tendency_5                     0           0           0           0
# cu_tendency_5                   0.2         0.4         0.4         0.6
# ft_tendency_5                     0           0           0           0
# ff_tendency_10             0.666667         0.6         0.7         0.6
# ch_tendency_10             0.111111         0.1         0.1         0.1
# cu_tendency_10             0.111111         0.2         0.2         0.3
# ft_tendency_10                    0           0           0           0
# ff_tendency_20             0.666667         0.6    0.636364    0.583333
# ch_tendency_20             0.111111         0.1   0.0909091   0.0833333
# cu_tendency_20             0.111111         0.2    0.181818        0.25
# ft_tendency_20                    0           0           0           0
# ff_count                          6           6           7           7
# ch_count                          1           1           1           1
# cu_count                          1           2           2           3
# ft_count                          0           0           0           0
# pitch_total_prior                 8           9          10          11
# score_margin                      0           0           0           0
# pitcher_advantage           neutral       ahead     neutral     neutral
# baserunner                    False       False       False       False
# at_bat_count                      3           3           3           3
# strike_pitch                     ff          cu       False       False
# strike_pitch_ff                   1           0           0           0
# strike_pitch_cu                   0           1           0           0
# strike_pitch_ft                   0           0           0           0
# strike_pitch_ch                   0           0           0           0
# ff_cumulative_strikes          0.75    0.666667         0.6    0.545455
# cu_cumulative_strikes             0    0.111111         0.1   0.0909091
# ft_cumulative_strikes             0           0           0           0
# ch_cumulative_strikes             0           0           0           0
# ff_strike_tendency_5              5           4           4           4
# cu_strike_tendency_5              0           1           1           1
# ft_strike_tendency_5              0           0           0           0
# ch_strike_tendency_5              0           0           0           0
#
#                                  12          13          14
# pitch_type                       ff          ft          cu
# game_date                2018-09-28  2018-09-28  2018-09-28
# stand                             R           L           R
# balls                             2           0           0
# strikes                           2           0           0
# on_3b                         False       False       False
# on_2b                         False       False       False
# on_1b                         False       False       False
# outs_when_up                      2           0           1
# inning                            1           2           2
# type                              S           X           S
# zone                              2          13           8
# previous_pitch                   cu          ff          ft
# strike_previous                True        True       False
# pitch_location_previous          14           2          13
# previous_pitch_ff                 0           1           0
# previous_pitch_ch                 0           0           0
# previous_pitch_cu                 1           0           0
# previous_pitch_ft                 0           0           1
# ff_tendency_5                   0.4         0.4         0.4
# ch_tendency_5                     0           0           0
# cu_tendency_5                   0.6         0.6         0.4
# ft_tendency_5                     0           0         0.2
# ff_tendency_10                  0.6         0.6         0.5
# ch_tendency_10                    0           0           0
# cu_tendency_10                  0.4         0.4         0.4
# ft_tendency_10                    0           0         0.1
# ff_tendency_20             0.538462    0.571429    0.533333
# ch_tendency_20            0.0769231   0.0714286   0.0666667
# cu_tendency_20             0.307692    0.285714    0.266667
# ft_tendency_20                    0           0   0.0666667
# ff_count                          7           8           8
# ch_count                          1           1           1
# cu_count                          4           4           4
# ft_count                          0           0           1
# pitch_total_prior                12          13          14
# score_margin                      0           1           1
# pitcher_advantage             ahead     neutral     neutral
# baserunner                    False       False       False
# at_bat_count                      3           4           5
# strike_pitch                     cu          ff       False
# strike_pitch_ff                   0           1           0
# strike_pitch_cu                   1           0           0
# strike_pitch_ft                   0           0           0
# strike_pitch_ch                   0           0           0
# ff_cumulative_strikes           0.5    0.538462         0.5
# cu_cumulative_strikes      0.166667    0.153846    0.142857
# ft_cumulative_strikes             0           0           0
# ch_cumulative_strikes             0           0           0
# ff_strike_tendency_5              3           3           3
# cu_strike_tendency_5              2           2           2
# ft_strike_tendency_5              0           0           0
# ch_strike_tendency_5              0           0           0

# %%
# %%capture
# raw_data = statcast_pitcher('2015-01-01', '2020-01-01', 621244)

# %%
target = 'pitch_type'
features = ['pitch_name', 'pitch_type', 'game_date', 'stand', 'balls', 
            'strikes', 'on_3b', 'on_2b', 'on_1b', 'outs_when_up', 'inning', 
            'at_bat_number', 'bat_score', 'fld_score', 'type', 'zone']

# %%
df = pd.DataFrame()

games = raw_data['game_date'].unique().tolist()
# this game is all NaN's, need to remove or write exception catcher
games.remove('2018-04-18')
# for game in games:
for game in games:
  game_data = wrangle_game(raw_data[raw_data['game_date'] == game][features])
  df = df.append(game_data, ignore_index=True, sort=False)

# %% [markdown]
# ## MODEL
#
# ---

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

# %%
backup = df

# %%
train, test = train_test_split(df, train_size=0.8, random_state=42)
train, val = train_test_split(train, train_size=0.8, random_state=42)
train.shape, val.shape, test.shape

# %%
target = 'pitch_type'
features = df.columns.drop([target, 'game_date'])

X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]
X_test = test[features]
y_test = test[target]

# %%
processor = make_pipeline(
    ce.OrdinalEncoder(),
    SimpleImputer(strategy='median')
)
X_train_processed = processor.fit_transform(X_train)
X_val_processed = processor.transform(X_val)

model = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
model.fit(X_train_processed, y_train)

print(f'Train accuracy: {model.score(X_train_processed, y_train):.5f}')
print(f'Validation accuracy: {model.score(X_val_processed, y_val):.5f}')

# %%
def log_model(txt_file='model_log.txt'):
    with open(txt_file, 'a') as file:
        file.write(f'Validation accuracy: {model.score(X_val_processed, y_val):.5f}\n')
        file.write(f'Features: {X_train.columns}\n')
        file.write(f'{model.get_params}\n')
        file.write('\n')
        file.close()
